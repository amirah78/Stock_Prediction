# %% [markdown]
# ### Install Packages (If any)

# %%
# Load required callbacks for model training
from tensorflow.keras.callbacks import EarlyStopping

# Load pretrained GloVe word embeddings
from gensim import downloader
model_glove = downloader.load("glove-wiki-gigaword-50")

# %% [markdown]
# ### Imports and Seed

# %%
import re
import numpy as np
import pandas as pd

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("stock_trend.csv")

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)

print("\nMissing values:\n", df.isna().sum())

# Show 10 lines (useful for rubric and sanity check)
df.head(10)
# Out:
# Shape: (24388, 6)
#
# Columns: ['Title', 'Time', 'Name', 'Quote', 'Before', 'After']
#
# Dtypes:
#  Title      object
# Time       object
# Name       object
# Quote       int64
# Before    float64
# After     float64
# dtype: object
#
# Missing values:
#  Title     0
# Time      0
# Name      0
# Quote     0
# Before    0
# After     0
# dtype: int64
#                                                Title  \
# 0  100 startups participate in Maxis' Market Acce...
# 1      16.89% stake in Subur Tiasa traded off-market
# 2  Najib wanted 1MDB's Genting Sanyen deal sped u...
# 3        25bps OPR cut likely in 2H20, says Manulife
# 4  A 25-month extension on concession pushes Phar...
# 5             3.7% of Yong Tai transacted off-market
# 6              3A, Ruberex, Thriven, Kanger, UniWall
# 7      40% stake in IWH-CREC may cost Ekovest RM1.5b
# 8      4.41% Kronologi Asia shares traded off-market
# 9                    4.96% of MMAG traded off market
#
#                         Time     Name  Quote  Before  After
# 0  2019-12-12T23:50:12+08:00    MAXIS   6012   5.160  5.110
# 1  2020-02-20T22:41:12+08:00    SUBUR   6904   0.610  0.610
# 2  2020-07-16T17:42:30+08:00  GENTING   3182   4.080  4.060
# 3  2020-01-16T17:03:43+08:00  MANULFE   1058   2.420  2.420
# 4  2019-11-11T10:49:58+08:00   PHARMA   7081   2.620  2.430
# 5  2019-09-05T19:55:54+08:00  YONGTAI   7066   0.195  0.200
# 6  2020-03-04T13:23:15+08:00   KANGER    170   0.125  0.120
# 7  2020-09-16T10:00:00+08:00  EKOVEST   8877   0.610  0.580
# 8  2020-02-12T23:54:51+08:00    KRONO    176   0.895  0.890
# 9  2019-07-23T22:42:17+08:00     MMAG     34   0.245  0.235

# %% [markdown]
# ### Data Cleaning

# %%
df = df.drop_duplicates()

df["Before"] = pd.to_numeric(df["Before"], errors="coerce")
df["After"]  = pd.to_numeric(df["After"],  errors="coerce")

df = df.dropna(subset=["Title", "Before", "After"])
df = df[df["Before"] > 0].copy()

print("After cleaning shape:", df.shape)

# Show 10 lines
df.head(10)
# Out:
# After cleaning shape: (24387, 6)
#                                                Title  \
# 0  100 startups participate in Maxis' Market Acce...
# 1      16.89% stake in Subur Tiasa traded off-market
# 2  Najib wanted 1MDB's Genting Sanyen deal sped u...
# 3        25bps OPR cut likely in 2H20, says Manulife
# 4  A 25-month extension on concession pushes Phar...
# 5             3.7% of Yong Tai transacted off-market
# 6              3A, Ruberex, Thriven, Kanger, UniWall
# 7      40% stake in IWH-CREC may cost Ekovest RM1.5b
# 8      4.41% Kronologi Asia shares traded off-market
# 9                    4.96% of MMAG traded off market
#
#                         Time     Name  Quote  Before  After
# 0  2019-12-12T23:50:12+08:00    MAXIS   6012   5.160  5.110
# 1  2020-02-20T22:41:12+08:00    SUBUR   6904   0.610  0.610
# 2  2020-07-16T17:42:30+08:00  GENTING   3182   4.080  4.060
# 3  2020-01-16T17:03:43+08:00  MANULFE   1058   2.420  2.420
# 4  2019-11-11T10:49:58+08:00   PHARMA   7081   2.620  2.430
# 5  2019-09-05T19:55:54+08:00  YONGTAI   7066   0.195  0.200
# 6  2020-03-04T13:23:15+08:00   KANGER    170   0.125  0.120
# 7  2020-09-16T10:00:00+08:00  EKOVEST   8877   0.610  0.580
# 8  2020-02-12T23:54:51+08:00    KRONO    176   0.895  0.890
# 9  2019-07-23T22:42:17+08:00     MMAG     34   0.245  0.235

# %% [markdown]
# ### Target Label (Trend)

# %% [markdown]
# Using relative price change

# %%
df["rel_change"] = (df["After"] - df["Before"]) / df["Before"]

def label_trend(x):
    if x > 0.009:
        return "uptrend"
    elif x < -0.009:
        return "downtrend"
    else:
        return "flat"

df["trend"] = df["rel_change"].apply(label_trend)

print(df["trend"].value_counts())

# Show 10 lines
df[["Title", "Before", "After", "rel_change", "trend"]].head(10)
# Out:
# trend
# flat         8711
# uptrend      8551
# downtrend    7125
# Name: count, dtype: int64
#                                                Title  Before  After  \
# 0  100 startups participate in Maxis' Market Acce...   5.160  5.110
# 1      16.89% stake in Subur Tiasa traded off-market   0.610  0.610
# 2  Najib wanted 1MDB's Genting Sanyen deal sped u...   4.080  4.060
# 3        25bps OPR cut likely in 2H20, says Manulife   2.420  2.420
# 4  A 25-month extension on concession pushes Phar...   2.620  2.430
# 5             3.7% of Yong Tai transacted off-market   0.195  0.200
# 6              3A, Ruberex, Thriven, Kanger, UniWall   0.125  0.120
# 7      40% stake in IWH-CREC may cost Ekovest RM1.5b   0.610  0.580
# 8      4.41% Kronologi Asia shares traded off-market   0.895  0.890
# 9                    4.96% of MMAG traded off market   0.245  0.235
#
#    rel_change      trend
# 0   -0.009690  downtrend
# 1    0.000000       flat
# 2   -0.004902       flat
# 3    0.000000       flat
# 4   -0.072519  downtrend
# 5    0.025641    uptrend
# 6   -0.040000  downtrend
# 7   -0.049180  downtrend
# 8   -0.005587       flat
# 9   -0.040816  downtrend

# %% [markdown]
# ### Text Normalization

# %%
def clean_text(s: str) -> str:
    s = str(s).lower()
    s = re.sub(r"http\S+|www\.\S+", " ", s)
    s = re.sub(r"[^a-z\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

df["text"] = df["Title"].apply(clean_text)

# Show 10 lines
df[["Title", "text", "trend"]].head(10)
# Out:
#                                                Title  \
# 0  100 startups participate in Maxis' Market Acce...
# 1      16.89% stake in Subur Tiasa traded off-market
# 2  Najib wanted 1MDB's Genting Sanyen deal sped u...
# 3        25bps OPR cut likely in 2H20, says Manulife
# 4  A 25-month extension on concession pushes Phar...
# 5             3.7% of Yong Tai transacted off-market
# 6              3A, Ruberex, Thriven, Kanger, UniWall
# 7      40% stake in IWH-CREC may cost Ekovest RM1.5b
# 8      4.41% Kronologi Asia shares traded off-market
# 9                    4.96% of MMAG traded off market
#
#                                                 text      trend
# 0    startups participate in maxis market access day  downtrend
# 1             stake in subur tiasa traded off market       flat
# 2  najib wanted mdb s genting sanyen deal sped up...       flat
# 3              bps opr cut likely in h says manulife       flat
# 4  a month extension on concession pushes pharman...  downtrend
# 5                  of yong tai transacted off market    uptrend
# 6                   a ruberex thriven kanger uniwall  downtrend
# 7            stake in iwh crec may cost ekovest rm b  downtrend
# 8            kronologi asia shares traded off market       flat
# 9                          of mmag traded off market  downtrend

# %% [markdown]
# ### Encode Labels

# %% [markdown]
# downtrend = 0 // flat = 1 // uptrend = 2

# %%
label2id = {"downtrend": 0, "flat": 1, "uptrend": 2}
id2label = {v: k for k, v in label2id.items()}

df["label"] = df["trend"].map(label2id)

print(df["label"].value_counts())

# Show 10 lines
df[["text", "trend", "label"]].head(10)
# Out:
# label
# 1    8711
# 2    8551
# 0    7125
# Name: count, dtype: int64
#                                                 text      trend  label
# 0    startups participate in maxis market access day  downtrend      0
# 1             stake in subur tiasa traded off market       flat      1
# 2  najib wanted mdb s genting sanyen deal sped up...       flat      1
# 3              bps opr cut likely in h says manulife       flat      1
# 4  a month extension on concession pushes pharman...  downtrend      0
# 5                  of yong tai transacted off market    uptrend      2
# 6                   a ruberex thriven kanger uniwall  downtrend      0
# 7            stake in iwh crec may cost ekovest rm b  downtrend      0
# 8            kronologi asia shares traded off market       flat      1
# 9                          of mmag traded off market  downtrend      0

# %% [markdown]
# ### Split Data

# %% [markdown]
# Train 70%, Validation 20%, Test 10%

# %%
from sklearn.model_selection import train_test_split

final_df = df[["text", "label", "trend", "Time", "Name", "Quote", "Before", "After", "rel_change"]].copy()

train_df, temp_df = train_test_split(
    final_df,
    test_size=0.30,
    random_state=SEED,
    stratify=final_df["label"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=(1/3),   # 10% out of total = 1/3 of the 30%
    random_state=SEED,
    stratify=temp_df["label"]
)

train_df = train_df.reset_index(drop=True)
val_df   = val_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

print("Train:", train_df.shape)
print("Val:  ", val_df.shape)
print("Test: ", test_df.shape)

print("\nTrain dist:\n", train_df["trend"].value_counts(normalize=True))
print("\nVal dist:\n", val_df["trend"].value_counts(normalize=True))
print("\nTest dist:\n", test_df["trend"].value_counts(normalize=True))

# Show 10 lines from each
train_df.head(10), val_df.head(10), test_df.head(10)
# Out:
# Train: (17070, 9)
# Val:   (4878, 9)
# Test:  (2439, 9)
#
# Train dist:
#  trend
# flat         0.357176
# uptrend      0.350674
# downtrend    0.292150
# Name: proportion, dtype: float64
#
# Val dist:
#  trend
# flat         0.357319
# uptrend      0.350554
# downtrend    0.292128
# Name: proportion, dtype: float64
#
# Test dist:
#  trend
# flat         0.357114
# uptrend      0.350554
# downtrend    0.292333
# Name: proportion, dtype: float64
# (                                                text  label      trend  \
#  0  public bank q net profit at rm b on revenue of...      1       flat
#  1  airasia group widad menang taliworks genting r...      1       flat
#  2  ralco bertam alliance cabnet chin hin group pr...      2    uptrend
#  3  time dotcom q net profit rises as revenue impr...      1       flat
#  4  marine general cahya mata sarawak fajarbaru ha...      2    uptrend
#  5  ijm plantations expects ffb yield to improve i...      0  downtrend
#  6   rex industry scraps rm m rights with bonus issue      1       flat
#  7  knm green packet mnc focus dynamics dgsb peste...      2    uptrend
#  8  airasia india rules out air india stake says r...      2    uptrend
#  9  third mb in two years nothing to be proud of s...      1       flat
#
#                          Time     Name  Quote  Before  After  rel_change
#  0  2018-05-02T13:12:51+08:00   PBBANK   1295   4.760  4.800    0.008403
#  1  2019-11-28T01:17:43+08:00     SIME   4197   2.300  2.300    0.000000
#  2  2021-02-16T13:49:51+08:00   SCABLE   5170   0.465  0.515    0.107527
#  3  2019-11-29T23:36:25+08:00  TIMECOM   5031   9.100  9.120    0.002198
#  4  2019-06-24T23:00:06+08:00      M&G   5078   0.075  0.085    0.133333
#  5  2018-07-06T11:04:11+08:00      IJM   3336   1.790  1.760   -0.016760
#  6  2018-04-12T17:23:04+08:00      REX   9946   0.343  0.343    0.000000
#  7  2019-07-05T13:34:24+08:00  GPACKET     82   0.380  0.390    0.026316
#  8  2018-01-17T12:58:45+08:00  AIRASIA   5099   3.860  3.900    0.010363
#  9  2020-12-10T16:33:26+08:00  PRKCORP   8346   0.190  0.190    0.000000  ,
#                                                  text  label    trend  \
#  0          latitude tree buys land in klang for rm m      1     flat
#  1  paramount corp q net profit falls to rm m in t...      2  uptrend
#  2  ihh maxis hektar reit bat mk land handal bina ...      1     flat
#  3                          qes down on profit taking      2  uptrend
#  4  united plantations declares dividends of rm share      1     flat
#  5    united malacca cut to market perform at kenanga      1     flat
#  6  g global green packet minda global mykris seal...      2  uptrend
#  7  gagasan nadi cergas malakoff corp dutaland sun...      2  uptrend
#  8  westports posts lower q earnings as container ...      1     flat
#  9  ablegroup gets sen a share takeover offer from md      1     flat
#
#                          Time      Name  Quote    Before     After  rel_change
#  0  2019-11-22T19:43:58+08:00   LATITUD   7006   2.90196   2.90196    0.000000
#  1  2019-08-22T20:22:36+08:00   PARAMON   1724   1.30000   1.32000    0.015385
#  2  2018-04-20T00:11:00+08:00    HEKTAR   5121   1.22000   1.23000    0.008197
#  3  2018-03-09T10:33:56+08:00       QES    196   0.22000   0.22500    0.022727
#  4  2018-02-26T11:34:17+08:00    UTDPLT   2089  14.34000  14.29000   -0.003487
#  5  2017-12-19T10:23:41+08:00     UMCCA   2593   6.52000   6.50000   -0.003067
#  6  2019-07-26T13:19:20+08:00   GPACKET     82   0.56500   0.59000    0.044248
#  7  2020-10-03T00:11:45+08:00  SUNSURIA   3743   0.40500   0.43000    0.061728
#  8  2018-04-26T10:43:57+08:00     WPRTS   5246   3.36000   3.39000    0.008929
#  9  2017-09-14T17:29:39+08:00   ABLEGRP   7086   0.14000   0.14000    0.000000  ,
#                                                  text  label      trend  \
#  0  serba dinamik fgv ikhmas jaya ireka symphony l...      2    uptrend
#  1  ytl power q net profit almost halves pays sen ...      2    uptrend
#  2             lay hong sterling pantech parkson wong      1       flat
#  3  advance synergy johore tin mui properties pan ...      2    uptrend
#  4  drb hicom sp setia dolphin kesm star media and...      2    uptrend
#  5  yinson kenanga investment bank wong engineerin...      2    uptrend
#  6  airasia serba dinamik lotus kfm knm group adva...      2    uptrend
#  7  country heights dialog sunway pharmaniaga para...      1       flat
#  8  sunway to develop rm m mixed development in ko...      1       flat
#  9  best non ipo fundraising bond sukuk press meta...      0  downtrend
#
#                          Time     Name  Quote    Before     After  rel_change
#  0  2018-04-09T22:48:13+08:00   UCREST      5  0.270000  0.310000    0.148148
#  1  2017-08-29T19:58:47+08:00      YTL   4677  1.328273  1.356736    0.021429
#  2  2017-10-02T13:14:20+08:00  PARKSON   5657  0.650000  0.645000   -0.007692
#  3  2020-10-09T13:32:15+08:00  WEGMANS    197  0.335000  0.345000    0.029851
#  4  2018-03-08T23:21:43+08:00      NWP   5025  0.235000  0.265000    0.127660
#  5  2020-04-02T00:11:14+08:00   YINSON   7293  4.690000  4.780000    0.019190
#  6  2020-07-07T23:37:59+08:00   ADVCON   5281  0.400000  0.410000    0.025000
#  7  2017-08-16T23:38:28+08:00   PHARMA   7081  4.190000  4.200000    0.002387
#  8  2019-07-01T13:33:52+08:00   SUNWAY   5211  1.673267  1.663366   -0.005917
#  9  2018-01-02T16:00:00+08:00   PMETAL   8869  5.390000  5.310000   -0.014842  )

# %% [markdown]
# ### Prepare Data

# %%
y_train = train_df["label"].values
y_val   = val_df["label"].values
y_test  = test_df["label"].values

print(y_train[:10])
# Out:
# [1 1 2 1 2 0 1 2 2 1]

# %% [markdown]
# ## LSTM : GloVe via gensim + TweetTokenizer

# %% [markdown]
# ### Setting parameter

# %%
sentence_length = 25
n_embedding = 50
n_output = 3
batch_size = 5
epochs = 50

# %% [markdown]
# ### Tokenize using TweetTokenizer

# %%
import nltk
nltk.download("punkt", quiet=True)

from nltk.tokenize import TweetTokenizer

tweet_tokenizer = TweetTokenizer()

def tokenize_sentence(s: str):
    s = s.lower()
    return tweet_tokenizer.tokenize(s)

# %% [markdown]
# ### OOV handling

# %% [markdown]
# Concert token -> embedding vectors

# %%
def tokens_to_vectors(tokens):
    vectors = []
    for tok in tokens:
        if tok in model_glove:
            vectors.append(model_glove[tok])
        else:
            vectors.append(np.zeros(n_embedding, dtype=np.float32))  # OOV
    return vectors

# %% [markdown]
# ### Normalize Vector

# %%
def normalize_vectors(vectors):
    out = []
    for v in vectors:
        norm = np.linalg.norm(v)
        if norm > 0:
            out.append((v / norm).astype(np.float32))
        else:
            out.append(v.astype(np.float32))
    return out

# %% [markdown]
# ### Build X-arrays

# %%
from gensim import downloader
model_glove = downloader.load("glove-wiki-gigaword-50")

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

def texts_to_padded_embeddings(text_series, do_normalize=True):
    seqs = []
    for s in text_series:
        tokens = tokenize_sentence(s)
        vecs = tokens_to_vectors(tokens)
        if do_normalize:
            vecs = normalize_vectors(vecs)
        seqs.append(vecs)
    
    X = pad_sequences(
        seqs,
        maxlen=sentence_length,
        dtype="float32",
        padding="post",
        truncating="post"
    )
    return X

X_train = texts_to_padded_embeddings(train_df["text"])
X_val   = texts_to_padded_embeddings(val_df["text"])
X_test  = texts_to_padded_embeddings(test_df["text"])

print("X_train shape:", X_train.shape)
print("X_val shape:  ", X_val.shape)
print("X_test shape: ", X_test.shape)

# Show 10 samples (short preview)
X_train[:10].shape
# Out:
# X_train shape: (17070, 25, 50)
# X_val shape:   (4878, 25, 50)
# X_test shape:  (2439, 25, 50)
# (10, 25, 50)

# %% [markdown]
# ### Build LSTM model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Flatten
from tensorflow.keras.models import Model

tf.random.set_seed(SEED)

inputs = Input(shape=(sentence_length, n_embedding))
lstm = LSTM(16, return_sequences=True, return_state=True)
outputs_seq, state_h, state_c = lstm(inputs)

flat = Flatten()(outputs_seq)
outputs = Dense(n_output, activation="softmax")(flat)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 25, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ [(None, 25, 16),       │         4,288 │
# │                                 │ (None, 16), (None,     │               │
# │                                 │ 16)]                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │         1,203 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,491 (21.45 KB)
#  Trainable params: 5,491 (21.45 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train model

# %%
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=2,
    min_delta=0.01,
    restore_best_weights=True
)

classes = np.unique(y_train)

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)

class_weight = dict(zip(classes, class_weights))

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    class_weight=class_weight,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 3414/3414 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.3865 - loss: 1.0908 - val_accuracy: 0.4036 - val_loss: 1.0832
# Epoch 2/50
# 3414/3414 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - accuracy: 0.4111 - loss: 1.0791 - val_accuracy: 0.4102 - val_loss: 1.0798
# Epoch 3/50
# 3414/3414 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.4203 - loss: 1.0715 - val_accuracy: 0.4114 - val_loss: 1.0787

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(
    y_test, y_pred,
    target_names=["downtrend", "flat", "uptrend"]
))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Test Accuracy: 0.4354243542435424
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    downtrend       0.43      0.13      0.20       713
#         flat       0.45      0.52      0.48       871
#      uptrend       0.43      0.60      0.50       855
#
#     accuracy                           0.44      2439
#    macro avg       0.43      0.42      0.39      2439
# weighted avg       0.43      0.44      0.41      2439

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 96, 287, 330],
#        [ 62, 453, 356],
#        [ 66, 276, 513]])

# %%
model.save("lstm_stock_trend_model.keras")

# Save splits if needed
train_df.to_csv("train_split.csv", index=False)
val_df.to_csv("val_split.csv", index=False)
test_df.to_csv("test_split.csv", index=False)
